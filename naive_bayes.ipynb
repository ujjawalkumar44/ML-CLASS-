# %% [markdown]
# First, let's import the necessary libraries and create some sample data. We'll use `make_classification` from `sklearn.datasets` for this purpose.

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# Generate sample data
X, y = make_classification(n_samples=1000, n_features=10, n_classes=2, random_state=42)

print(f"Shape of features (X): {X.shape}")
print(f"Shape of target (y): {y.shape}")
# Out:
# Shape of features (X): (1000, 10)
# Shape of target (y): (1000,)

# %% [markdown]
# Next, we'll split the data into training and testing sets. This allows us to train the model on one subset of the data and evaluate its performance on unseen data.

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Shape of training features (X_train): {X_train.shape}")
print(f"Shape of testing features (X_test): {X_test.shape}")
print(f"Shape of training target (y_train): {y_train.shape}")
print(f"Shape of testing target (y_test): {y_test.shape}")
# Out:
# Shape of training features (X_train): (700, 10)
# Shape of testing features (X_test): (300, 10)
# Shape of training target (y_train): (700,)
# Shape of testing target (y_test): (300,)

# %% [markdown]
# Now, we'll train a Gaussian Naive Bayes classifier. This type of Naive Bayes is suitable for continuous data, assuming a Gaussian distribution for each class.

# %%
# Initialize the Gaussian Naive Bayes classifier
model = GaussianNB()

# Train the model
model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %% [markdown]
# Finally, we'll make predictions on the test set and evaluate the model's performance using accuracy score and a classification report.

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.83
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82       135
#            1       0.90      0.78      0.83       165
#
#     accuracy                           0.83       300
#    macro avg       0.83      0.83      0.83       300
# weighted avg       0.84      0.83      0.83       300

# %% [markdown]
# Let's visualize the model's performance using a confusion matrix. This will help us understand where the model is performing well and where it might be making mistakes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0 (Predicted)', 'Class 1 (Predicted)'],
            yticklabels=['Class 0 (Actual)', 'Class 1 (Actual)'])
plt.title('Confusion Matrix for Gaussian Naive Bayes Classifier')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
